# %% [markdown]
# <a href="https://colab.research.google.com/github/manusri-kim/fmml2021/blob/main/datavizpysessioniiith.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import random

# %%
y = np.random.rand(100) #gives random numbers

# %%
print(y)
# Out:
# [0.97664596 0.02641799 0.72001082 0.37302665 0.90572971 0.68452096
#  0.63637422 0.38244802 0.54044978 0.14408953 0.80765849 0.8351061
#  0.30316617 0.97696314 0.28870592 0.06327102 0.79166746 0.33960434
#  0.59967307 0.85574808 0.46158968 0.38910452 0.18432261 0.65505155
#  0.51219894 0.09873539 0.43810583 0.93579013 0.60864535 0.03363395
#  0.38770023 0.44917316 0.37713553 0.64558034 0.45456341 0.83525176
#  0.5283486  0.24572138 0.51504062 0.40274823 0.51680967 0.48546823
#  0.39879636 0.79812843 0.61091677 0.43890364 0.14315107 0.83277046
#  0.63498209 0.18848731 0.20453313 0.45944581 0.73978791 0.54499505
#  0.96633563 0.04594406 0.3632223  0.27789123 0.63182267 0.08969773
#  0.7710694  0.475211   0.18240457 0.40872868 0.82054661 0.65829166
#  0.067824   0.37195224 0.81343346 0.5060352  0.02750208 0.40750633
#  0.1809417  0.22088389 0.25503247 0.68022222 0.19052267 0.00479909
#  0.55162889 0.34037661 0.21997899 0.61279547 0.58658082 0.55951374
#  0.04063636 0.21706711 0.68845468 0.22761033 0.91763216 0.98095915
#  0.88420251 0.92063076 0.10789156 0.92995957 0.899629   0.75899864
#  0.08868822 0.33428716 0.93295597 0.1388967 ]

# %%
x = np.linspace(0,10,100) #equally distanced numbers 
print(x)
# Out:
# [ 0.          0.1010101   0.2020202   0.3030303   0.4040404   0.50505051
#   0.60606061  0.70707071  0.80808081  0.90909091  1.01010101  1.11111111
#   1.21212121  1.31313131  1.41414141  1.51515152  1.61616162  1.71717172
#   1.81818182  1.91919192  2.02020202  2.12121212  2.22222222  2.32323232
#   2.42424242  2.52525253  2.62626263  2.72727273  2.82828283  2.92929293
#   3.03030303  3.13131313  3.23232323  3.33333333  3.43434343  3.53535354
#   3.63636364  3.73737374  3.83838384  3.93939394  4.04040404  4.14141414
#   4.24242424  4.34343434  4.44444444  4.54545455  4.64646465  4.74747475
#   4.84848485  4.94949495  5.05050505  5.15151515  5.25252525  5.35353535
#   5.45454545  5.55555556  5.65656566  5.75757576  5.85858586  5.95959596
#   6.06060606  6.16161616  6.26262626  6.36363636  6.46464646  6.56565657
#   6.66666667  6.76767677  6.86868687  6.96969697  7.07070707  7.17171717
#   7.27272727  7.37373737  7.47474747  7.57575758  7.67676768  7.77777778
#   7.87878788  7.97979798  8.08080808  8.18181818  8.28282828  8.38383838
#   8.48484848  8.58585859  8.68686869  8.78787879  8.88888889  8.98989899
#   9.09090909  9.19191919  9.29292929  9.39393939  9.49494949  9.5959596
#   9.6969697   9.7979798   9.8989899  10.        ]

# %%
#lineplot
plt.plot(x)
plt.plot(y)

# %%
#lineplot with diff functions
plt.plot(x,np.cos(x),color = "purple", marker = "*")
plt.plot(x,np.sin(x),color = "magenta", marker = "*")
#hash info will be removed with 
#plt.show()or we can use semicolon aswell
plt.xlabel("sample")
plt.ylabel("sin/cos")
plt.title("linegraph")
#canhaveseperate plots with 
#plt.subplot(1,2,1)(numerofrows,numberofcoloumns,index)
# Out:
# Text(0.5, 1.0, 'linegraph')

# %%
cars_data = pd.read_csv('ToyotaCorolla.csv')

# %%
cars_data.shape
# Out:
# (1436, 37)

# %%
print(type(cars_data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
cars_data.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Automatic', 'cc', 'Doors', 'Cylinders',
#        'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee', 'BOVAG_Guarantee',
#        'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2', 'Airco',
#        'Automatic_airco', 'Boardcomputer', 'CD_Player', 'Central_Lock',
#        'Powered_Windows', 'Power_Steering', 'Radio', 'Mistlamps',
#        'Sport_Model', 'Backseat_Divider', 'Metallic_Rim', 'Radio_cassette',
#        'Tow_Bar'],
#       dtype='object')

# %%
cars_trim = cars_data[['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
       'Fuel_Type', 'HP', 'Met_Color', 'Automatic', 'cc', 'Doors', 'Cylinders',
       'Gears','Weight']]

# %%
cars_trim.shape
# Out:
# (1436, 16)

# %%
cars_trim.describe()
# Out:
#                 Id         Price  ...        Gears      Weight
# count  1436.000000   1436.000000  ...  1436.000000  1436.00000
# mean    721.555014  10730.824513  ...     5.026462  1072.45961
# std     416.476890   3626.964585  ...     0.188510    52.64112
# min       1.000000   4350.000000  ...     3.000000  1000.00000
# 25%     361.750000   8450.000000  ...     5.000000  1040.00000
# 50%     721.500000   9900.000000  ...     5.000000  1070.00000
# 75%    1081.250000  11950.000000  ...     5.000000  1085.00000
# max    1442.000000  32500.000000  ...     6.000000  1615.00000
#
# [8 rows x 14 columns]

# %%
#scatterplot
plt.scatter(cars_trim.Age_08_04,cars_trim['Price'])#teo different ways of referring

# %%
plt.title("age vs price")
plt.xlabel("age in months")
plt.ylabel("price in $")
plt.scatter(cars_trim.Age_08_04,cars_trim['Price'])

# %%
#Histograms
min(cars_trim['Price'])
max(cars_trim['Price'])
plt.hist(cars_trim['Price'],bins=5)
# Out:
# (array([816., 457., 134.,  26.,   3.]),
#  array([ 4350.,  9980., 15610., 21240., 26870., 32500.]),
#  <a list of 5 Patch objects>)

# %%
#barcharts
cars_trim['Fuel_Type'].unique()
# Out:
# array(['Diesel', 'Petrol', 'CNG'], dtype=object)

# %%
cars_trim['Fuel_Type'][cars_trim['Fuel_Type']=='Petrol'].count()
# Out:
# 1264

# %%
#groupby 
carss = cars_trim.groupby( 'Fuel_Type' )['Fuel_Type'].count()

# %%
plt.bar(cars_trim['Fuel_Type'].unique(),carss[cars_trim['Fuel_Type'].unique()]);

# %%
plt.bar(carss.keys(),carss[carss.keys()])
# Out:
# <BarContainer object of 3 artists>

# %%
#piechart 
plt.pie(carss,labels=carss.keys(),autopct='%.2f%%')#first %.2f ctype syntax for numbrs , next%%for printing %symbol;

# %%
plt.pie(carss,labels=carss.keys(),autopct='%.2f%%',explode=[1,0,0],startangle = 90);

# %%
plt.pie(carss,labels=carss.keys(),autopct='%.2f%%',wedgeprops=dict(width=0.3));

# %%
sns.regplot(cars_trim['Age_08_04'],cars_trim['Price']);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
